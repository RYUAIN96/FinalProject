# %%
import pandas as pd

# %%
yelp = pd.read_csv("./data/yelf_add_menu.csv")

# %%
yelp
# Out:
#        Unnamed: 0  Unnamed: 0.1             business_id                 date  \
# 0               0            67  2AS4HuJJHTBG6R8D9ldrdA  2018-02-24 02:52:41
# 1               1            68  2AS4HuJJHTBG6R8D9ldrdA  2017-06-17 23:39:45
# 2               2            69  2AS4HuJJHTBG6R8D9ldrdA  2018-03-16 07:51:57
# 3               3            70  2AS4HuJJHTBG6R8D9ldrdA  2014-12-01 00:15:41
# 4               4            71  2AS4HuJJHTBG6R8D9ldrdA  2015-08-21 01:37:51
# ...           ...           ...                     ...                  ...
# 77397       77397        129725  59OgPGGzKFYqwSG_U06kuA  2019-12-10 02:10:44
# 77398       77398        129726  Mglgm8rfJxZ0LLgN23YGOg  2014-04-22 02:53:17
# 77399       77399        129727  Mglgm8rfJxZ0LLgN23YGOg  2013-03-05 21:15:24
# 77400       77400        129728  Mglgm8rfJxZ0LLgN23YGOg  2014-06-22 17:57:16
# 77401       77401        129729  Mglgm8rfJxZ0LLgN23YGOg  2015-03-28 14:19:47
#
#                     review_id stars                 user_id  \
# 0      7S5VnFLaAMpXtMByAqzIAg   5.0  KgQnRvsPSrJJTOCp-reYZA
# 1      s55cQLpbeAbwkZXCL1KeEQ   5.0  1goJa-4OKwc--vlISRm54g
# 2      rb-c59Bbr8zy3BOcIuVIjA   4.0  6agrhhelmT9DLUfx4EeZVA
# 3      h9OWeU5tx2H9UCh1_ErhHg   5.0  AvaeN3hgxdytAEMlNud-FQ
# 4      WmnupTn8LgKaDCUsRXHIDQ   2.0  wML8YiFzB1JuCfyhPptiSg
# ...                       ...   ...                     ...
# 77397  rvRgvUDVUcOwtrq09ELBMQ   5.0  BJnwgclUI15lNRaf1s9GOg
# 77398  IS5p7043wm0RSaoRaYT7SA   5.0  U5YQX_vMl_xQy8EQDqlNQQ
# 77399  Cox8HkY0r4DZVqrOFXbxCw   5.0  ci8R1Bg83hNwXPyHAEzAFA
# 77400  Mkn0EEIeoe2-ocIl1JAfKA   3.0  CxDOIDnH8gp9KXzpBHJYXw
# 77401  IDCIg8PF5NSW67DC0CksDw   5.0  MF-4u5xl0MoAvSdLf6tK7w
#
#                                                     text  \
# 0      We have been here three times now and have lov...
# 1      Seoul Garden was excellent.  We moved to this ...
# 2      I like this place a lot. One of the best Korea...
# 3      Korean Barbecue at its finest. The outside doe...
# 4      Food was ok. The food looks good in pictures b...
# ...                                                  ...
# 77397  A hole in the wall location. Wasn't expecting ...
# 77398  I was torn whether or not to give this place 4...
# 77399  A very interesting little place for kimchi lov...
# 77400  Maybe I have a hgh expectation with Kimchi Kor...
# 77401  I love getting my kimchi here because rather t...
#
#                                 categories            city  \
# 0                      Korean, Restaurants  Cuyahoga Falls
# 1                      Korean, Restaurants  Cuyahoga Falls
# 2                      Korean, Restaurants  Cuyahoga Falls
# 3                      Korean, Restaurants  Cuyahoga Falls
# 4                      Korean, Restaurants  Cuyahoga Falls
# ...                                    ...             ...
# 77397                  Restaurants, Korean        Chandler
# 77398  Korean, Food, Shopping, Restaurants     Mississauga
# 77399  Korean, Food, Shopping, Restaurants     Mississauga
# 77400  Korean, Food, Shopping, Restaurants     Mississauga
# 77401  Korean, Food, Shopping, Restaurants     Mississauga
#
#                                  name state  \
# 0      Seoul Garden Korean Restaurant    OH
# 1      Seoul Garden Korean Restaurant    OH
# 2      Seoul Garden Korean Restaurant    OH
# 3      Seoul Garden Korean Restaurant    OH
# 4      Seoul Garden Korean Restaurant    OH
# ...                               ...   ...
# 77397                         Chodang    AZ
# 77398                    Kimchi Korea    ON
# 77399                    Kimchi Korea    ON
# 77400                    Kimchi Korea    ON
# 77401                    Kimchi Korea    ON
#
#                                                     menu
# 0      ['bulgogi', 'galbigui', 'kimchijjigae', 'doenj...
# 1      ['bulgogi', 'galbigui', 'kimchijjigae', 'doenj...
# 2      ['bulgogi', 'galbigui', 'kimchijjigae', 'doenj...
# 3      ['bulgogi', 'galbigui', 'kimchijjigae', 'doenj...
# 4      ['bulgogi', 'galbigui', 'kimchijjigae', 'doenj...
# ...                                                  ...
# 77397                                  ['sundubujjigae']
# 77398                      ['bibimbap', 'sundubujjigae']
# 77399                      ['bibimbap', 'sundubujjigae']
# 77400                      ['bibimbap', 'sundubujjigae']
# 77401                      ['bibimbap', 'sundubujjigae']
#
# [77402 rows x 13 columns]

# %%
yelp = yelp.drop(["Unnamed: 0"], axis=1)

# %%
yelp = yelp.drop(["Unnamed: 0.1"], axis=1)

# %%
yelp.head(2)
# Out:
#               business_id                 date               review_id stars  \
# 0  2AS4HuJJHTBG6R8D9ldrdA  2018-02-24 02:52:41  7S5VnFLaAMpXtMByAqzIAg   5.0
# 1  2AS4HuJJHTBG6R8D9ldrdA  2017-06-17 23:39:45  s55cQLpbeAbwkZXCL1KeEQ   5.0
#
#                   user_id                                               text  \
# 0  KgQnRvsPSrJJTOCp-reYZA  We have been here three times now and have lov...
# 1  1goJa-4OKwc--vlISRm54g  Seoul Garden was excellent.  We moved to this ...
#
#             categories            city                            name state  \
# 0  Korean, Restaurants  Cuyahoga Falls  Seoul Garden Korean Restaurant    OH
# 1  Korean, Restaurants  Cuyahoga Falls  Seoul Garden Korean Restaurant    OH
#
#                                                 menu
# 0  ['bulgogi', 'galbigui', 'kimchijjigae', 'doenj...
# 1  ['bulgogi', 'galbigui', 'kimchijjigae', 'doenj...

# %%
yelp = yelp.rename({"stars" : "rating",
                   "user_id" : "user_name",
                   "text" : "review",
                   "name" : "res_name"}, axis="columns")

# %%
yelp.head(1)
# Out:
#               business_id                 date               review_id rating  \
# 0  2AS4HuJJHTBG6R8D9ldrdA  2018-02-24 02:52:41  7S5VnFLaAMpXtMByAqzIAg    5.0
#
#                 user_name                                             review  \
# 0  KgQnRvsPSrJJTOCp-reYZA  We have been here three times now and have lov...
#
#             categories            city                        res_name state  \
# 0  Korean, Restaurants  Cuyahoga Falls  Seoul Garden Korean Restaurant    OH
#
#                                                 menu
# 0  ['bulgogi', 'galbigui', 'kimchijjigae', 'doenj...

# %%
yelp_end = yelp[["user_name", "res_name", "rating", "review", "menu"]]

# %%
yelp_end.head(1)
# Out:
#                 user_name                        res_name rating  \
# 0  KgQnRvsPSrJJTOCp-reYZA  Seoul Garden Korean Restaurant    5.0
#
#                                               review  \
# 0  We have been here three times now and have lov...
#
#                                                 menu
# 0  ['bulgogi', 'galbigui', 'kimchijjigae', 'doenj...

# %%
yelp_end.to_csv("./data/yelp_end.csv")
